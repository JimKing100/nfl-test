# %% [markdown]
# <a href="https://colab.research.google.com/github/JimKing100/nfl-test/blob/master/predictions/Predictions_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import pandas as pd

# %%
# Load the data
defense_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-predictions/week1-pred-defense.csv')
offense_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-predictions/week1-pred-offense-norookies.csv')
rookies_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-predictions/week1-pred-offense-rookies.csv')

# %%
# Merge the three prediction files - defense, offense with no rookies and the rookies
predictions_df = pd.concat([defense_df, offense_df, rookies_df], ignore_index=True)

# %%
predictions_df.head()
# Out:
#   player          first     last  ... week1-act week1-diff  week1-pct
# 0     SF  San Francisco    49ers  ...     140.0 -36.000000  -0.346154
# 1    CHI        Chicago    Bears  ...      90.0  49.955511   0.356939
# 2    CIN     Cincinnati  Bengals  ...      63.0  46.315789   0.423688
# 3    BUF        Buffalo    Bills  ...     122.0 -10.354151  -0.092741
# 4    DEN         Denver  Broncos  ...      92.0  26.950706   0.226570
#
# [5 rows x 9 columns]

# %%
predictions_df.tail()
# Out:
#       player    first      last  ... week1-act week1-diff  week1-pct
# 610  SS-0650  Spencer   Schnell  ...       0.0  27.506823   1.000000
# 611  SS-1537   Steven  Sims Jr.  ...      77.5 -67.356803  -6.640589
# 612  TF-1450   Travis   Fulgham  ...       0.0   9.184027   1.000000
# 613  TM-2275    Terry  McLaurin  ...     137.9 -79.739123  -1.371010
# 614  VB-0325  Ventell    Bryant  ...       7.5  13.069206   0.635377
#
# [5 rows x 9 columns]

# %%
predictions_df['rank-pred'] = predictions_df['week1-pred'].rank(ascending=False)
predictions_df['rank-act'] = predictions_df['week1-act'].rank(ascending=False)

# %%
predictions_df.head()
# Out:
#   player          first     last  ... week1-pct rank-pred  rank-act
# 0     SF  San Francisco    49ers  ... -0.346154     152.0      81.5
# 1    CHI        Chicago    Bears  ...  0.356939      99.0     159.0
# 2    CIN     Cincinnati  Bengals  ...  0.423688     140.0     217.5
# 3    BUF        Buffalo    Bills  ... -0.092741     137.0     111.0
# 4    DEN         Denver  Broncos  ...  0.226570     122.0     150.5
#
# [5 rows x 11 columns]

# %%
predictions_df = predictions_df.sort_values(by=['rank-pred'])

# %%
predictions_df.head(50)
# Out:
#       player     first            last  ... week1-pct rank-pred  rank-act
# 84   JA-1087      Josh           Allen  ...  0.837981       1.0       8.0
# 88   LJ-0150     Lamar         Jackson  ...  0.639605       2.0       1.0
# 398  JK-2250      Jake         Kumerow  ...  0.962783       3.0     322.5
# 171  DC-3550    Dalvin            Cook  ...  0.624369       4.0      22.0
# 80   NM-0687      Nick         Mullens  ...  1.000472       5.0     605.0
# 409  DR-2225  Demarcus        Robinson  ...  0.888487       6.0     203.0
# 312  IT-0150       Ian          Thomas  ...  0.965560       7.0     369.0
# 201  JS-0280    Jaylen         Samuels  ...  0.883591       8.0     228.0
# 482  DB-5912   Deontay         Burnett  ...  0.989598       9.0     481.5
# 179  MM-0050    Marlon            Mack  ...  0.628830      10.0      56.0
# 286  BJ-0950     Blake          Jarwin  ...  0.872737      11.0     232.0
# 168  CC-0750     Chris          Carson  ...  0.505182      12.0      37.0
# 508  VS-0175   Vyncint           Smith  ...  0.929626      13.0     334.0
# 491  JW-0934     James      Washington  ...  0.742209      14.0     152.0
# 78   DW-1725   Deshaun          Watson  ...  0.061528      15.0       5.0
# 136  TG-1950      Todd          Gurley  ...  0.453088      16.0      43.0
# 148  DW-1550    Dwayne      Washington  ...  0.980817      17.0     457.0
# 195  GE-0150       Gus         Edwards  ...  0.734812      18.0     162.0
# 485  DH-1050   DaeSean        Hamilton  ...  0.891680      19.0     301.0
# 464  ZJ-0100       Zay           Jones  ...  0.933360      20.0     360.0
# 76   JD-2850      Jeff         Driskel  ...  0.815968      21.0     226.0
# 503  RJ-0450    Richie           James  ...  0.928978      22.0     357.5
# 57   RW-3850   Russell          Wilson  ... -0.087757      23.0       4.0
# 213  RF-1400     Royce         Freeman  ...  0.672490      24.0     146.0
# 39   AR-1300     Aaron         Rodgers  ...  0.045150      25.0      11.0
# 53   KC-2350      Kirk         Cousins  ...  0.104191      26.0      18.0
# 43   MR-2500      Matt            Ryan  ...  0.032424      27.0      14.0
# 38   PR-0300    Philip          Rivers  ...  0.128003      28.0      23.0
# 74   DP-2037       Dak        Prescott  ... -0.261801      29.0       3.0
# 294  GK-0075    George          Kittle  ...  0.486479      30.0      83.0
# 174  JM-5275       Joe           Mixon  ...  0.289590      31.0      40.0
# 145  DH-2450   Derrick           Henry  ... -0.074670      32.0      10.0
# 32   TB-2300       Tom           Brady  ... -0.015178      33.0      15.0
# 79   MT-1800  Mitchell        Trubisky  ...  0.220327      34.0      35.0
# 466  AC-0237   Antonio        Callaway  ...  0.965779      35.0     440.0
# 33   DB-3800      Drew           Brees  ...  0.118895      36.0      27.0
# 52   CK-0250      Case          Keenum  ...  0.581107      37.0     133.0
# 81   PM-0025   Patrick         Mahomes  ... -0.182677      38.0       7.0
# 49   CN-0500       Cam          Newton  ...  0.933189      39.0     387.0
# 366  DA-0212   Davante           Adams  ...  0.477575      40.0      98.0
# 166  AK-0050     Alvin          Kamara  ...  0.296797      41.0      55.0
# 68   JW-5650    Jameis         Winston  ... -0.282930      42.0       6.0
# 458  MW-2825      Mike        Williams  ...  0.520068      43.0     121.0
# 352  DH-3950   DeAndre         Hopkins  ...  0.300526      44.0      57.0
# 35   BR-1100       Ben  Roethlisberger  ...  0.946388      45.0     406.0
# 36   EM-0200       Eli         Manning  ...  0.750776      46.0     233.0
# 194  DW-3243    Darrel        Williams  ...  0.765540      47.0     244.0
# 156  KD-1462    Kenyan           Drake  ...  0.251517      48.0      58.0
# 77   JG-1850     Jared            Goff  ... -0.130336      49.0      19.0
# 339  JJ-4700     Julio           Jones  ...  0.192479      50.0      47.0
#
# [50 rows x 11 columns]

# %%
# Save the results to .csv file
predictions_df.to_csv('/content/predictions-week1.csv', index=False)
