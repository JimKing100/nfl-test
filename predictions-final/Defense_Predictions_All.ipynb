# %% [markdown]
# <a href="https://colab.research.google.com/github/JimKing100/nfl-test/blob/master/predictions-final/Defense_Predictions_All.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installs
# %%capture
# !pip install pmdarima

# %%
# Imports
import numpy as np
import pandas as pd
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
from sklearn import preprocessing
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Import data
original_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-actuals/actuals_defense.csv')
player_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-revised/players.csv')
bye_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-revised/bye.csv')

# %%
# The dataframe of actual defense points for each game from 2000-2019
original_df.head()
# Out:
#   player          first     last  ... 2019-game14 2019-game15  2019-game16
# 0     SF  San Francisco    49ers  ...           1           7            1
# 1    CHI        Chicago    Bears  ...           1           1            8
# 2    CIN     Cincinnati  Bengals  ...           1           1           12
# 3    BUF        Buffalo    Bills  ...          17           2            7
# 4    DEN         Denver  Broncos  ...           5           5            5
#
# [5 rows x 325 columns]

# %%
# The dataframe of all 2019 players
player_df.head()
# Out:
#   player          first     last                 name position1  start
# 0     SF  San Francisco    49ers  San Francisco 49ers        DF   2000
# 1    CHI        Chicago    Bears        Chicago Bears        DF   2000
# 2    CIN     Cincinnati  Bengals   Cincinnati Bengals        DF   2000
# 3    BUF        Buffalo    Bills        Buffalo Bills        DF   2000
# 4    DEN         Denver  Broncos       Denver Broncos        DF   2000

# %%
# The dataframe of bye weeks for 2019 teams
bye_df.head()
# Out:
#   player          first     last                 name position1  bye-week
# 0     SF  San Francisco    49ers  San Francisco 49ers        DF         4
# 1    CHI        Chicago    Bears        Chicago Bears        DF         6
# 2    CIN     Cincinnati  Bengals   Cincinnati Bengals        DF         9
# 3    BUF        Buffalo    Bills        Buffalo Bills        DF         6
# 4    DEN         Denver  Broncos       Denver Broncos        DF        10

# %%
# Add a row to the final_df dataframe
# Each row represents the predicted points for each team
def add_row(df, p, f, l, n, pos, wc, wp, wa, cur, pred, act):

    df = df.append({'player': p,
                    'first': f,
                    'last': l,
                    'name': n,
                    'position': pos,
                    wc: cur,
                    wp: pred,
                    wa: act
                    }, ignore_index=True)
    
    return df

# %%
# The main code for iterating through the player(defense) list, calculating the points and adding the rows
# to the final_df dataframe.
def main(w):
    week_cname = 'week' + str(w) + '-cur'
    week_pname = 'week' + str(w) + '-pred'
    week_aname = 'week' + str(w) + '-act'

    column_names = ['player',
                    'first',
                    'last',
                    'name',
                    'position',
                    week_cname, 
                    week_pname,
                    week_aname
                     ]

    defense_df = player_df.loc[player_df['position1'] == 'DF']
    player_list = defense_df['player'].tolist()
    row = 0
    col = 308 + w

    week_df = pd.DataFrame(columns = column_names)

    for player in player_list:

        first = player_df['first'].loc[(player_df['player']==player)].iloc[0]
        last = player_df['last'].loc[(player_df['player']==player)].iloc[0]
        name = player_df['name'].loc[(player_df['player']==player)].iloc[0]
        position1 = player_df['position1'].loc[(player_df['player']==player)].iloc[0]

        bye_week = bye_df['bye-week'].loc[(bye_df['player']==player)].iloc[0]

        if w > bye_week:
            new_col = col - 1
        else:
            new_col = col

        if player == 'HOU':
            train_data = original_df.iloc[row, 37:new_col]
        else:
            train_data = original_df.iloc[row, 5:new_col]

        if w == 1:
            current = original_df.iloc[row, 293:309]
        else:
            current = original_df.iloc[row, 309:new_col]
        cur_points = current.sum()

        actuals = original_df.iloc[row, new_col:325]
        act_points = actuals.sum()
        row = row + 1

        # ARIMA model
        model = pm.auto_arima(train_data, start_p=1, start_q=1,
                          test='adf',       # use adftest to find optimal 'd'
                          max_p=3, max_q=3, # maximum p and q
                          m=1,              # frequency of series
                          d=None,           # let model determine 'd'
                          seasonal=False,   # No Seasonality
                          start_P=0, 
                          D=0, 
                          trace=False,
                          error_action='ignore',  
                          suppress_warnings=True, 
                          stepwise=True)
    
        # Forecast
        if w > bye_week:
            n_periods = 17 - w + 1
        else:
            n_periods = 17 - w
        print(n_periods)
        fc = model.predict(n_periods=n_periods, return_conf_int=False)
        index_of_fc = np.arange(len(train_data), len(train_data)+n_periods)
        fc_series = pd.Series(fc, index=index_of_fc)
        pred_points = fc_series.sum()

        week_df = add_row(week_df, player, first, last, name, position1, week_cname, 
                          week_pname, week_aname, cur_points, pred_points, act_points)
    return week_df

# %%
for i in range(1, 18):
    week = i
    final_df = main(week)

    week_pred = 'week' + str(week) + '-pred'
    week_act = 'week' + str(week) + '-act'
    week_diff = 'week' + str(week) + '-diff'
    week_pct = 'week' + str(week) + '-pct'

    final_df[week_diff] = final_df[week_pred] - final_df[week_act]
    final_df[week_pct] = final_df[week_diff] / final_df[week_pred]
    final_df[week_pred] = final_df[week_pred].astype(int)

    file_name = '/content/week' + str(week) + '-pred-defense.csv'
    final_df.to_csv(file_name, index=False)
# Out:
# SF
# 4
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1928.353, BIC=1943.221, Time=0.079 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1924.396, BIC=1931.830, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1926.362, BIC=1937.513, Time=0.057 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1926.364, BIC=1937.516, Time=0.077 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2175.948, BIC=2179.665, Time=0.009 seconds
# Total fit time: 0.245 seconds
# 16
# CHI
# 6
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1982.774, BIC=1997.642, Time=0.359 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1992.064, BIC=1999.498, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1990.874, BIC=2002.025, Time=0.076 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1991.038, BIC=2002.189, Time=0.098 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2288.351, BIC=2292.068, Time=0.009 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1984.734, BIC=2003.319, Time=0.537 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1984.724, BIC=2003.309, Time=0.503 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1992.946, BIC=2007.814, Time=0.131 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1992.474, BIC=2007.342, Time=0.154 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1986.456, BIC=2008.758, Time=0.619 seconds
# Near non-invertible roots for order (2, 0, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Total fit time: 2.508 seconds
# 16
# CIN
# 9
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1919.279, BIC=1934.148, Time=0.094 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1915.334, BIC=1922.768, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1917.279, BIC=1928.430, Time=0.087 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1917.275, BIC=1928.427, Time=0.057 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2189.782, BIC=2193.499, Time=0.008 seconds
# Total fit time: 0.264 seconds
# 16
# BUF
# 6
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1979.838, BIC=1994.706, Time=0.084 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1977.967, BIC=1985.401, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1977.841, BIC=1988.992, Time=0.056 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1977.829, BIC=1988.980, Time=0.069 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2222.017, BIC=2225.734, Time=0.009 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1979.828, BIC=1994.697, Time=0.130 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1981.828, BIC=2000.414, Time=0.118 seconds
# Total fit time: 0.486 seconds
# 16
# DEN
# 10
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1923.199, BIC=1938.067, Time=0.476 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1924.844, BIC=1932.278, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1926.692, BIC=1937.843, Time=0.055 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1926.707, BIC=1937.858, Time=0.082 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2224.789, BIC=2228.506, Time=0.009 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1924.448, BIC=1943.033, Time=0.554 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1924.407, BIC=1942.992, Time=0.610 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1927.977, BIC=1942.845, Time=0.137 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1927.855, BIC=1942.723, Time=0.122 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1926.602, BIC=1948.904, Time=0.706 seconds
# Total fit time: 2.775 seconds
# 16
# CLE
# 7
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1862.514, BIC=1877.382, Time=0.299 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1861.558, BIC=1868.992, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1863.546, BIC=1874.698, Time=0.082 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1863.545, BIC=1874.696, Time=0.055 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2132.051, BIC=2135.768, Time=0.008 seconds
# Total fit time: 0.463 seconds
# 16
# TB
# 7
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1963.553, BIC=1978.422, Time=0.475 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1973.669, BIC=1981.103, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1975.112, BIC=1986.263, Time=0.051 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1975.168, BIC=1986.319, Time=0.082 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2257.123, BIC=2260.840, Time=0.008 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1965.935, BIC=1984.520, Time=0.579 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1965.156, BIC=1983.741, Time=0.649 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1976.331, BIC=1991.199, Time=0.122 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1976.064, BIC=1990.932, Time=0.156 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1967.355, BIC=1989.658, Time=0.804 seconds
# Near non-invertible roots for order (2, 0, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Total fit time: 2.950 seconds
# 16
# ARI
# 12
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1985.112, BIC=1999.980, Time=0.314 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1983.147, BIC=1990.581, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1984.908, BIC=1996.059, Time=0.058 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1984.914, BIC=1996.065, Time=0.087 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2236.521, BIC=2240.238, Time=0.009 seconds
# Total fit time: 0.488 seconds
# 16
# LAC
# 12
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1906.537, BIC=1921.405, Time=0.088 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1902.605, BIC=1910.039, Time=0.018 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1904.550, BIC=1915.701, Time=0.058 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1904.552, BIC=1915.703, Time=0.080 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2193.406, BIC=2197.123, Time=0.008 seconds
# Total fit time: 0.258 seconds
# 16
# KC
# 12
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1945.738, BIC=1960.606, Time=0.159 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1943.863, BIC=1951.297, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1944.767, BIC=1955.918, Time=0.059 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1944.570, BIC=1955.721, Time=0.057 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2207.306, BIC=2211.023, Time=0.008 seconds
# Total fit time: 0.302 seconds
# 16
# IND
# 6
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1909.375, BIC=1924.244, Time=0.090 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1905.628, BIC=1913.062, Time=0.013 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1907.376, BIC=1918.527, Time=0.051 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1907.376, BIC=1918.527, Time=0.064 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2185.024, BIC=2188.741, Time=0.008 seconds
# Total fit time: 0.232 seconds
# 16
# DAL
# 8
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1868.411, BIC=1883.279, Time=0.242 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1864.615, BIC=1872.049, Time=0.013 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1866.547, BIC=1877.699, Time=0.081 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1866.541, BIC=1877.692, Time=0.058 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2152.925, BIC=2156.642, Time=0.008 seconds
# Total fit time: 0.408 seconds
# 16
# MIA
# 5
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1963.040, BIC=1977.908, Time=0.288 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1960.036, BIC=1967.470, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1961.652, BIC=1972.803, Time=0.085 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1961.626, BIC=1972.777, Time=0.054 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2225.290, BIC=2229.007, Time=0.008 seconds
# Total fit time: 0.453 seconds
# 16
# PHI
# 10
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1948.986, BIC=1963.854, Time=0.201 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1946.837, BIC=1954.271, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1947.007, BIC=1958.159, Time=0.083 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1947.049, BIC=1958.200, Time=0.055 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2256.846, BIC=2260.563, Time=0.008 seconds
# Total fit time: 0.367 seconds
# 16
# ATL
# 9
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1901.871, BIC=1916.739, Time=0.093 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1898.387, BIC=1905.821, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1899.852, BIC=1911.003, Time=0.051 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1899.830, BIC=1910.981, Time=0.064 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2178.415, BIC=2182.132, Time=0.008 seconds
# Total fit time: 0.234 seconds
# 16
# NYG
# 11
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1954.148, BIC=1969.016, Time=0.243 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1955.904, BIC=1963.338, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1956.963, BIC=1968.114, Time=0.093 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1956.805, BIC=1967.956, Time=0.067 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2226.370, BIC=2230.087, Time=0.008 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1955.875, BIC=1974.460, Time=0.331 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1955.893, BIC=1974.479, Time=0.280 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1956.815, BIC=1971.683, Time=0.071 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1957.517, BIC=1972.385, Time=0.124 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1958.020, BIC=1980.323, Time=0.228 seconds
# Total fit time: 1.469 seconds
# 16
# JAC
# 10
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1870.246, BIC=1885.114, Time=0.394 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1875.634, BIC=1883.068, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1876.943, BIC=1888.094, Time=0.050 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1877.117, BIC=1888.268, Time=0.084 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2143.031, BIC=2146.748, Time=0.009 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1858.765, BIC=1877.350, Time=0.286 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1870.703, BIC=1885.571, Time=0.116 seconds
# Fit ARIMA: (3, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1859.145, BIC=1881.447, Time=0.329 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1857.381, BIC=1879.683, Time=0.432 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1856.556, BIC=1875.141, Time=0.289 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1870.862, BIC=1885.730, Time=0.127 seconds
# Fit ARIMA: (1, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=1857.961, BIC=1880.263, Time=0.369 seconds
# Fit ARIMA: (0, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=1867.283, BIC=1885.868, Time=0.145 seconds
# Fit ARIMA: (2, 0, 3)x(0, 0, 0, 0) (constant=True); AIC=1857.938, BIC=1883.957, Time=0.700 seconds
# Near non-invertible roots for order (2, 0, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.997)
# Total fit time: 3.355 seconds
# 16
# NYJ
# 4
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1909.370, BIC=1924.238, Time=0.495 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1913.645, BIC=1921.079, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1915.201, BIC=1926.352, Time=0.054 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1915.255, BIC=1926.406, Time=0.069 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2183.839, BIC=2187.556, Time=0.009 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1911.534, BIC=1930.119, Time=0.563 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1911.370, BIC=1929.955, Time=0.656 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1916.028, BIC=1930.896, Time=0.118 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1915.706, BIC=1930.574, Time=0.123 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1911.850, BIC=1934.152, Time=0.702 seconds
# Total fit time: 2.813 seconds
# 16
# DET
# 5
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1936.491, BIC=1951.359, Time=0.219 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1933.311, BIC=1940.745, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1934.694, BIC=1945.845, Time=0.078 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1934.746, BIC=1945.897, Time=0.078 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2182.085, BIC=2185.802, Time=0.012 seconds
# Total fit time: 0.407 seconds
# 16
# GB
# 11
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1970.685, BIC=1985.553, Time=0.078 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1966.915, BIC=1974.349, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1968.691, BIC=1979.842, Time=0.149 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1968.687, BIC=1979.838, Time=0.076 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2261.974, BIC=2265.691, Time=0.009 seconds
# Total fit time: 0.333 seconds
# 16
# CAR
# 7
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1927.780, BIC=1942.648, Time=0.512 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1924.482, BIC=1931.916, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1925.969, BIC=1937.120, Time=0.084 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1925.980, BIC=1937.131, Time=0.082 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2231.421, BIC=2235.138, Time=0.009 seconds
# Total fit time: 0.707 seconds
# 16
# NE
# 10
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1939.261, BIC=1954.129, Time=0.185 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1942.513, BIC=1949.947, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1941.517, BIC=1952.668, Time=0.091 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1940.887, BIC=1952.038, Time=0.087 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2278.421, BIC=2282.138, Time=0.009 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1940.772, BIC=1959.357, Time=0.313 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1940.891, BIC=1959.476, Time=0.243 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1940.179, BIC=1955.047, Time=0.096 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1941.642, BIC=1956.510, Time=0.142 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1939.639, BIC=1961.941, Time=0.689 seconds
# Total fit time: 1.883 seconds
# 16
# OAK
# 6
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1872.931, BIC=1887.799, Time=0.456 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1883.955, BIC=1891.389, Time=0.016 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1881.817, BIC=1892.968, Time=0.090 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1882.748, BIC=1893.899, Time=0.078 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2125.099, BIC=2128.816, Time=0.013 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1879.032, BIC=1897.617, Time=0.469 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1874.839, BIC=1893.424, Time=0.716 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1879.009, BIC=1893.877, Time=0.113 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1878.083, BIC=1892.951, Time=0.124 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1875.929, BIC=1898.231, Time=0.699 seconds
# Total fit time: 2.783 seconds
# 16
# LA
# 9
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1974.757, BIC=1989.625, Time=0.236 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1971.640, BIC=1979.074, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1972.760, BIC=1983.911, Time=0.071 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1972.786, BIC=1983.938, Time=0.077 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2225.017, BIC=2228.734, Time=0.009 seconds
# Total fit time: 0.412 seconds
# 16
# BAL
# 8
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1998.042, BIC=2012.910, Time=0.287 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1994.687, BIC=2002.121, Time=0.025 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1996.403, BIC=2007.554, Time=0.058 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1996.446, BIC=2007.597, Time=0.060 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2313.169, BIC=2316.886, Time=0.009 seconds
# Total fit time: 0.443 seconds
# 16
# WAS
# 10
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1805.248, BIC=1820.116, Time=0.172 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1801.690, BIC=1809.124, Time=0.014 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1803.255, BIC=1814.406, Time=0.089 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1803.263, BIC=1814.414, Time=0.048 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2110.161, BIC=2113.878, Time=0.009 seconds
# Total fit time: 0.337 seconds
# 16
# NO
# 9
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1933.934, BIC=1948.802, Time=0.444 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1933.580, BIC=1941.014, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1935.519, BIC=1946.670, Time=0.092 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1935.533, BIC=1946.684, Time=0.083 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2185.634, BIC=2189.351, Time=0.009 seconds
# Total fit time: 0.650 seconds
# 16
# SEA
# 11
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1962.011, BIC=1976.879, Time=0.357 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1959.284, BIC=1966.718, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1960.712, BIC=1971.863, Time=0.074 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1960.617, BIC=1971.768, Time=0.079 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2257.041, BIC=2260.758, Time=0.009 seconds
# Total fit time: 0.538 seconds
# 16
# PIT
# 7
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1910.894, BIC=1925.762, Time=0.269 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1910.374, BIC=1917.808, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1911.739, BIC=1922.890, Time=0.086 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1911.798, BIC=1922.949, Time=0.067 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2252.537, BIC=2256.254, Time=0.008 seconds
# Total fit time: 0.450 seconds
# 16
# HOU
# 10
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1737.260, BIC=1751.683, Time=0.370 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1734.169, BIC=1741.380, Time=0.013 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1735.827, BIC=1746.644, Time=0.051 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1735.849, BIC=1746.667, Time=0.070 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=1947.739, BIC=1951.345, Time=0.008 seconds
# Total fit time: 0.517 seconds
# 16
# TEN
# 11
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1961.559, BIC=1976.427, Time=0.459 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1961.763, BIC=1969.197, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1963.615, BIC=1974.766, Time=0.053 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1963.642, BIC=1974.793, Time=0.080 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2224.869, BIC=2228.586, Time=0.009 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1963.115, BIC=1981.700, Time=0.442 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1963.143, BIC=1981.728, Time=0.269 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1961.628, BIC=1976.497, Time=0.104 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1961.734, BIC=1976.602, Time=0.159 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1964.831, BIC=1987.133, Time=0.675 seconds
# Total fit time: 2.272 seconds
# 16
# MIN
# 12
# 309
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1964.954, BIC=1979.822, Time=0.521 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1962.970, BIC=1970.404, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1964.637, BIC=1975.788, Time=0.093 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1964.674, BIC=1975.825, Time=0.088 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2217.881, BIC=2221.598, Time=0.013 seconds
# Total fit time: 0.735 seconds
# 16
