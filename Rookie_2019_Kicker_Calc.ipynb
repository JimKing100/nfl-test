# %% [markdown]
# <a href="https://colab.research.google.com/github/JimKing100/nfl-test/blob/master/Rookie_2019_Kicker_Calc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import pandas as pd

# %%
# Load the raw data
rookie_kicker_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-revised/rookies.csv')
kicking_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-revised/kicking.csv')
missed_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-revised/missedfg.csv')
conv_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-revised/conv.csv')

# %%
# The dataframe of all 2019 rookie kickers
rookie_kicker_df.head()
# Out:
#     player   first        last              name position1  start
# 0  MG-0306    Matt         Gay          Matt Gay         K   2019
# 1  CM-2137   Chase  McLaughlin  Chase McLaughlin         K   2019
# 2  AS-0575  Austin     Seibert    Austin Seibert         K   2019
# 3  JS-3825    Joey        Slye         Joey Slye         K   2019
# 4  DB-2750   David      Blough      David Blough        QB   2019

# %%
# The kicking dataframe - raw kicking data for all 2019 kickers for seasons 2000-2019
kicking_df.head()
# Out:
#    uid  gid   player   del first       last  ... fgl  fp  game  seas  year  team
# 0   15    8  AV-0400  KEEP  Adam  Vinatieri  ...   0   4     1     5  2000    NE
# 1   59   30  AV-0400  KEEP  Adam  Vinatieri  ...   0  13     2     5  2000    NE
# 2   76   38  AV-0400  KEEP  Adam  Vinatieri  ...   0   1     3     5  2000    NE
# 3  100   51  AV-0400  KEEP  Adam  Vinatieri  ...   0   4     4     5  2000    NE
# 4  122   63  AV-0400  KEEP  Adam  Vinatieri  ...   0   4     5     5  2000    NE
#
# [5 rows x 17 columns]

# %%
# The missed field goal dataframe - raw missed field goal data for all 2019 kickers for seasons 2000-2019
missed_df.head()
# Out:
#     pid  gid  year  week fgxp  ... first       last            name dist  good
# 0   517    4  2000     1   FG  ...  John       Hall       John Hall   52     0
# 1   583    4  2000     1   FG  ...  John       Hall       John Hall   48     0
# 2   877    6  2000     1   FG  ...  Kris    Heppner    Kris Heppner   52     0
# 3  1203    8  2000     1   FG  ...  Adam  Vinatieri  Adam Vinatieri   55     0
# 4  1435    9  2000     1   FG  ...  Doug      Brien      Doug Brien   52     0
#
# [5 rows x 11 columns]

# %%
# Pull the stats to calculate the kicker points - the fp column is the points total for each game
def pull_stats(df, df1, df2, df3, col, p, y, g):
    missedfg_points = 0
    conversion_points = 0
    if (df[col].loc[(df['name']==p) & (df['year']==y) & (df['game']==g)].empty):
        start_year = df1['start'].loc[(df1['name']==p)].iloc[0]
        if y < start_year:
            points = float('NaN')
        else:
            points = 0
    else:
        conversion_points1 = df3['conv'].loc[(df3['name_bc']==p) & (df3['year']==y) & (df3['week']==g)].count()
        conversion_points2 = df3['conv'].loc[(df3['name_psr']==p) & (df3['year']==y) & (df3['week']==g)].count()
        conversion_points3 = df3['conv'].loc[(df3['name_trg']==p) & (df3['year']==y) & (df3['week']==g)].count()

        conversion_points = conversion_points1 + conversion_points2 + conversion_points3
        missedfg_points = df2['good'].loc[(df2['name']==p) & (df2['year']==y) & (df2['week']==g)].count()
        points = df[col].loc[(df['name']==p) & (df['year']==y) & (df['game']==g)].iloc[0]

    return points - missedfg_points + conversion_points

# %%
# Add a row to the final_df dataframe
# Each row represents the actual kicking points for each game for each kicker
def add_row(df, p, f, l, n, pos, value_list):

    df = df.append({'player': p,
                    'first': f,
                    'last': l,
                    'name': n,
                    'position1': pos,
                    'game1': value_list[0], 
                    'game2': value_list[1],
                    'game3': value_list[2], 
                    'game4': value_list[3], 
                    'game5': value_list[4], 
                    'game6': value_list[5], 
                    'game7': value_list[6], 
                    'game8': value_list[7], 
                    'game9': value_list[8],
                    'game10': value_list[9],
                    'game11': value_list[10],
                    'game12': value_list[11],
                    'game13': value_list[12],
                    'game14': value_list[13],
                    'game15': value_list[14],
                    'game16': value_list[15]
                    }, ignore_index=True)
    
    return df

# %%
# The main code for iterating through the kicker list, calculating the points and adding the rows
# to the final_df dataframe.
column_names = ['player',
                'first',
                'last',
                'name',
                'position1', 
                'game1',
                'game2',
                'game3', 
                'game4', 
                'game5', 
                'game6', 
                'game7', 
                'game8', 
                'game9',
                'game10',
                'game11',
                'game12',
                'game13',
                'game14',
                'game15',
                'game16'
                ]

kicker_df = rookie_kicker_df.loc[(rookie_kicker_df['position1'] == 'K')]
player_list = kicker_df['name'].tolist()

final_df = pd.DataFrame(columns = column_names)

for player in player_list:

    first = rookie_kicker_df['first'].loc[(rookie_kicker_df['name']==player)].iloc[0]
    last = rookie_kicker_df['last'].loc[(rookie_kicker_df['name']==player)].iloc[0]
    name = rookie_kicker_df['name'].loc[(rookie_kicker_df['name']==player)].iloc[0]
    position1 = rookie_kicker_df['position1'].loc[(rookie_kicker_df['name']==player)].iloc[0]
    year = rookie_kicker_df['start'].loc[(rookie_kicker_df['name']==player)].iloc[0]

    player_scores = []

    for game in range(1,17):
        score = pull_stats(kicking_df, rookie_kicker_df, missed_df, conv_df, 'fp', player, year, game)

        player_scores.append(score)

    final_df = add_row(final_df, player, first, last, name, position1, player_scores)

# %%
final_df.head(50)
# Out:
#              player   first        last  ... game14 game15 game16
# 0          Matt Gay    Matt         Gay  ...      9     10      1
# 1  Chase McLaughlin   Chase  McLaughlin  ...      0      0      0
# 2    Austin Seibert  Austin     Seibert  ...      7      3      6
# 3         Joey Slye    Joey        Slye  ...      8      8      4
#
# [4 rows x 21 columns]

# %%
# Save the results to .csv file
final_df.to_csv('/content/actuals_rookie2019_kickers.csv', index=False)
