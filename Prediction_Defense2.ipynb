# %% [markdown]
# <a href="https://colab.research.google.com/github/JimKing100/nfl-test/blob/master/Prediction_Defense2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installs
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.6/dist-packages (1.5.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: statsmodels>=0.10.2 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.10.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.25.3)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.18.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.29.15)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from statsmodels>=0.10.2->pmdarima) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.4.0->statsmodels>=0.10.2->pmdarima) (1.12.0)

# %%
# Imports
import numpy as np
import pandas as pd
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
from sklearn import preprocessing

# %%
# Import data
original_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-actuals/actuals_defense.csv')
player_df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/nfl-test/master/data-revised/players.csv')

# %%
# The dataframe of actual defense points for each game from 2000-2019
original_df.head()
# Out:
#   player          first     last  ... 2019-game14 2019-game15  2019-game16
# 0     SF  San Francisco    49ers  ...           1           7            1
# 1    CHI        Chicago    Bears  ...           1           1            8
# 2    CIN     Cincinnati  Bengals  ...           1           1           12
# 3    BUF        Buffalo    Bills  ...          17           2            7
# 4    DEN         Denver  Broncos  ...           5           5            5
#
# [5 rows x 325 columns]

# %%
# The dataframe of all 2019 players
player_df.head()
# Out:
#   player          first     last                 name position1  start
# 0     SF  San Francisco    49ers  San Francisco 49ers        DF   2000
# 1    CHI        Chicago    Bears        Chicago Bears        DF   2000
# 2    CIN     Cincinnati  Bengals   Cincinnati Bengals        DF   2000
# 3    BUF        Buffalo    Bills        Buffalo Bills        DF   2000
# 4    DEN         Denver  Broncos       Denver Broncos        DF   2000

# %%
# Add a row to the final_df dataframe
# Each row represents the predicted points for each team
def add_row(df, p, f, l, n, pos, pts):

    df = df.append({'player': p,
                    'first': f,
                    'last': l,
                    'name': n,
                    'position1': pos,
                    'week1-pts': pts
                    }, ignore_index=True)
    
    return df

# %%
# The main code for iterating through the player(defense) list, calculating the points and adding the rows
# to the final_df dataframe.
column_names = ['player',
                'first',
                'last',
                'name',
                'position1', 
                'week1-pts'
                 ]

defense_df = player_df.loc[player_df['position1'] == 'DF']
player_list = defense_df['player'].tolist()
row = 0

final_df = pd.DataFrame(columns = column_names)

for player in player_list:

    first = player_df['first'].loc[(player_df['player']==player)].iloc[0]
    last = player_df['last'].loc[(player_df['player']==player)].iloc[0]
    name = player_df['name'].loc[(player_df['player']==player)].iloc[0]
    position1 = player_df['position1'].loc[(player_df['player']==player)].iloc[0]

    if player == 'HOU':
        train_data = original_df.iloc[row, 37:309]
    else:
        train_data = original_df.iloc[row, 5:309]
    row = row + 1
    print(player)

    # ARIMA model
    model = pm.auto_arima(train_data, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
    
    # Forecast
    n_periods = 16
    fc = model.predict(n_periods=n_periods, return_conf_int=False)
    index_of_fc = np.arange(len(train_data), len(train_data)+n_periods)
    fc_series = pd.Series(fc, index=index_of_fc)
    points = fc_series.sum()

    final_df = add_row(final_df, player, first, last, name, position1, points)
# Out:
# SF
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1928.353, BIC=1943.221, Time=0.082 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1924.396, BIC=1931.830, Time=0.016 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1926.362, BIC=1937.513, Time=0.074 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1926.364, BIC=1937.516, Time=0.093 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2175.948, BIC=2179.665, Time=0.010 seconds
# Total fit time: 0.285 seconds
# CHI
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1910.894, BIC=1925.762, Time=0.307 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1910.374, BIC=1917.808, Time=0.017 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1911.739, BIC=1922.890, Time=0.098 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1911.798, BIC=1922.949, Time=0.100 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2252.537, BIC=2256.254, Time=0.011 seconds
# Total fit time: 0.538 seconds
# HOU
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1737.260, BIC=1751.683, Time=0.431 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1734.169, BIC=1741.380, Time=0.015 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1735.827, BIC=1746.644, Time=0.059 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1735.849, BIC=1746.667, Time=0.079 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=1947.739, BIC=1951.345, Time=0.010 seconds
# Total fit time: 0.602 seconds
# TEN
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1961.559, BIC=1976.427, Time=0.510 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1961.763, BIC=1969.197, Time=0.016 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1963.615, BIC=1974.766, Time=0.061 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1963.642, BIC=1974.793, Time=0.092 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2224.869, BIC=2228.586, Time=0.010 seconds
# Fit ARIMA: (2, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1963.115, BIC=1981.700, Time=0.489 seconds
# Fit ARIMA: (1, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1963.143, BIC=1981.728, Time=0.310 seconds
# Fit ARIMA: (0, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1961.628, BIC=1976.497, Time=0.116 seconds
# Fit ARIMA: (2, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1961.734, BIC=1976.602, Time=0.185 seconds
# Fit ARIMA: (2, 0, 2)x(0, 0, 0, 0) (constant=True); AIC=1964.831, BIC=1987.133, Time=0.775 seconds
# Total fit time: 2.575 seconds
# MIN
# Performing stepwise search to minimize aic
# Fit ARIMA: (1, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1964.954, BIC=1979.822, Time=0.608 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1962.970, BIC=1970.404, Time=0.016 seconds
# Fit ARIMA: (1, 0, 0)x(0, 0, 0, 0) (constant=True); AIC=1964.637, BIC=1975.788, Time=0.101 seconds
# Fit ARIMA: (0, 0, 1)x(0, 0, 0, 0) (constant=True); AIC=1964.674, BIC=1975.825, Time=0.110 seconds
# Fit ARIMA: (0, 0, 0)x(0, 0, 0, 0) (constant=False); AIC=2217.881, BIC=2221.598, Time=0.011 seconds
# Total fit time: 0.852 seconds

# %%
# The final_df dataframe
final_df.head(50)
# Out:
#    player          first  ... position1   week1-pts
# 0      SF  San Francisco  ...        DF  104.000000
# 1     CHI        Chicago  ...        DF  139.955511
# 2     CIN     Cincinnati  ...        DF  109.315789
# 3     BUF        Buffalo  ...        DF  111.645849
# 4     DEN         Denver  ...        DF  118.950706
# 5     CLE      Cleveland  ...        DF   98.973684
# 6      TB      Tampa Bay  ...        DF   97.970050
# 7     ARI        Arizona  ...        DF  115.157895
# 8     LAC    Los Angeles  ...        DF  111.894737
# 9      KC    Kansas City  ...        DF  111.105263
# 10    IND   Indianapolis  ...        DF  109.052632
# 11    DAL         Dallas  ...        DF  104.421053
# 12    MIA          Miami  ...        DF  114.684211
# 13    PHI   Philadelphia  ...        DF  126.526316
# 14    ATL        Atlanta  ...        DF  107.947368
# 15    NYG       New York  ...        DF  115.422541
# 16    JAC   Jacksonville  ...        DF  108.363250
# 17    NYJ       New York  ...        DF   90.120700
# 18    DET        Detroit  ...        DF  104.684211
# 19     GB      Green Bay  ...        DF  125.789474
# 20    CAR       Carolina  ...        DF  121.000000
# 21     NE    New England  ...        DF  135.101195
# 22    OAK        Oakland  ...        DF   65.902408
# 23     LA    Los Angeles  ...        DF  113.000000
# 24    BAL      Baltimore  ...        DF  139.868421
# 25    WAS     Washington  ...        DF   99.263158
# 26     NO    New Orleans  ...        DF  105.736842
# 27    SEA        Seattle  ...        DF  125.105263
# 28    PIT     Pittsburgh  ...        DF  129.105263
# 29    HOU        Houston  ...        DF  102.411765
# 30    TEN      Tennessee  ...        DF  113.932483
# 31    MIN      Minnesota  ...        DF  111.894737
#
# [32 rows x 6 columns]
